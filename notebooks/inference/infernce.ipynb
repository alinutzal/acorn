# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys

import numpy as np
import pandas as pd
import scipy.sparse as sps
import yaml
from itertools import chain, product, combinations
import torch

from time import time as tt
from tqdm import tqdm
sys.path.append("../../../")

from gnn4itk_cf.core.infer_stage import infer
from gnn4itk_cf.core.eval_stage import evaluate
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
config_dr = "../examples/Example_3/data_reader.yaml"
config_mm = "../examples/Example_3/metric_learning_infer.yaml"
config_ft = "../examples/Example_3/filter_infer.yaml"
config_gnn = "../examples/Example_3/gnn_infer.yaml"
config_tbi = "../examples/Example_3/track_building_infer.yaml"
config_tbe = "../examples/Example_3/track_building_eval.yaml"

# %%
#infer(config_dr )
#infer(config_mm)
#infer(config_ft)
#infer(config_gnn)
#infer(config_tbi)
evaluate(config_tbe)
# Out:
# Plotting tracking efficiency vs. pT
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 23.82it/s]
# Number of reconstructed particles: 4723
# Number of particles: 11394
# Number of matched tracks: 6041
# Number of tracks: 8231
# Number of duplicate reconstructed particles: 1308
# Efficiency: 0.415
# Fake rate: 0.266
# Duplication rate: 0.277
