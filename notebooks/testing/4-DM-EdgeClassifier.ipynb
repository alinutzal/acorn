# %% [markdown]
# # Edge Classifier Debug

# %% [markdown]
# **Goal**: Test the weighting and hard cut config of the data loading process

# %%
# %load_ext autoreload
# %autoreload 2

import os
import yaml

import numpy as np
import pandas as pd
import seaborn as sns
import yaml
import torch
from torch_geometric.data import Data
import matplotlib.pyplot as plt
#from torch_geometric.utils import to_dgl
from time import time as tt
import dgl
from torch_geometric.data import Data, HeteroData

# %%
def to_dgl(data):
    if isinstance(data, Data):
        if data.edge_index is not None:
            row, col = data.edge_index
        else:
            row, col, _ = data.adj_t.t().coo()

        g = dgl.graph((row, col))

        #for attr in data.node_attrs():
        #    g.ndata[attr] = data[attr]
        #for attr in data.edge_attrs():
        #    if attr in ['edge_index', 'adj_t']:
        #        continue
        
        g.edata = data.edge_index
        g.ndata = data.x

        return g

    raise ValueError(f"Invalid data type (got '{type(data)}')")

# %%
edge_index = torch.tensor([[0, 1, 1, 2, 3, 0], [1, 0, 2, 1, 4, 4]])
x = torch.randn(5, 3)
edge_attr = torch.randn(6, 2)
data = Data(x=x, edge_index=edge_index, edge_attrs=edge_attr)
g = to_dgl(data)
g
#Graph(num_nodes=5, num_edges=6,
#    ndata_schemes={'x': Scheme(shape=(3,))}
#    edata_schemes={'edge_attr': Scheme(shape=(2, ))})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb Cell 7 line 5
#       <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y253sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> edge_attr = torch.randn(6, 2)
#       <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y253sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> data = Data(x=x, edge_index=edge_index, edge_attrs=edge_attr)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y253sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> g = to_dgl(data)
#       <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y253sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> g
#
# /users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb Cell 7 line 1
#       <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y253sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> g = dgl.graph((row, col))
#      <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y253sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> #for attr in data.node_attrs():
#      <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y253sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> #    g.ndata[attr] = data[attr]
#      <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y253sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> #for attr in data.edge_attrs():
#      <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y253sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> #    if attr in ['edge_index', 'adj_t']:
#      <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y253sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> #        continue
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y253sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> g.edata = data.edge_index
#      <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y253sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> g.ndata = data.x
#      <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y253sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> return g
#
# AttributeError: can't set attribute

# %% [markdown]
# ## GNN Debug

# %%
from gnn4itk_cf.stages.edge_classifier.models.interaction_gnn import InteractionGNN
# Out:
# WARNING:root:FRNN is not available, install it at https://github.com/murnanedaniel/FRNN. Using PyG radius instead.
# WARNING:root:FRNN is not available, as no GPU is available
# WARNING:root:cuDF not found, using pandas instead
# WARNING:root:cuDF not found, using pandas instead

# %%
config = yaml.load(open('gnn_train.yaml'), Loader=yaml.FullLoader)
model = InteractionGNN(config)
model.setup('fit')
# Out:
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [particle_id] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [nhits] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [primary] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [pdgId] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [ghost] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [shared] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [module_id] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [region] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [hit_id] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [pt] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# Defining figures of merit
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/stages/edge_classifier/edge_classifier_stage.py:74: UserWarning: Failed to define figures of merit, due to logger unavailable
#   warnings.warn("Failed to define figures of merit, due to logger unavailable")

# %%
event1
# Out:
# DataBatch(hit_id=[94112], x=[94112], y=[430879], z=[94112], r=[94112], phi=[94112], eta=[94112], region=[94112], module_index=[94112], weight=[94112], cell_count=[94112], cell_val=[94112], leta=[94112], lphi=[94112], lx=[94112], ly=[94112], lz=[94112], geta=[94112], gphi=[94112], track_edges=[2, 85285], particle_id=[85285], pt=[85285], radius=[85285], nhits=[85285], config=[2], event_id=[1], num_nodes=94112, batch=[94112], ptr=[2], edge_index=[2, 430879], truth_map=[85285], weights=[430879])

# %%
event1 = model.trainset[1]
test = event1.x

print("min:",torch.min(test))
print("max:",torch.max(test))
# Out:
# min: tensor(-1024.5500, dtype=torch.float64)
# max: tensor(1025.1100, dtype=torch.float64)

# %%
g = to_dgl(model.trainset[0])
g
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/umap3/lib/python3.8/site-packages/torch_geometric/data/storage.py:62, in BaseStorage.__getattr__(self, key)
#      61 try:
# ---> 62     return self[key]
#      63 except KeyError:
#
# File ~/.conda/envs/umap3/lib/python3.8/site-packages/torch_geometric/data/storage.py:85, in BaseStorage.__getitem__(self, key)
#      84 def __getitem__(self, key: str) -> Any:
# ---> 85     return self._mapping[key]
#
# KeyError: 'node_attrs'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y260sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> g = to_dgl(model.trainset[0])
#       <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y260sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> g
#
# /users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb Cell 10 line 1
#       <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y260sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     row, col, _ = data.adj_t.t().coo()
#       <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y260sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> g = dgl.graph((row, col))
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y260sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> for attr in data.node_attrs():
#      <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y260sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     g.ndata[attr] = data[attr]
#      <a href='vscode-notebook-cell://ssh-remote%2Bpitzer/users/PLS0150/ialadutska/data/CommonFramework/notebooks/testing/4-DM-EdgeClassifier.ipynb#Y260sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> for attr in data.edge_attrs():
#
# File ~/.conda/envs/umap3/lib/python3.8/site-packages/torch_geometric/data/data.py:428, in Data.__getattr__(self, key)
#     422 if '_store' not in self.__dict__:
#     423     raise RuntimeError(
#     424         "The 'data' object was created by an older version of PyG. "
#     425         "If this error occurred while loading an already existing "
#     426         "dataset, remove the 'processed/' directory in the dataset's "
#     427         "root folder and try again.")
# --> 428 return getattr(self._store, key)
#
# File ~/.conda/envs/umap3/lib/python3.8/site-packages/torch_geometric/data/storage.py:64, in BaseStorage.__getattr__(self, key)
#      62     return self[key]
#      63 except KeyError:
# ---> 64     raise AttributeError(
#      65         f"'{self.__class__.__name__}' object has no attribute '{key}'")
#
# AttributeError: 'GlobalStorage' object has no attribute 'node_attrs'

# %%
numNodes = np.zeros(100, dtype=int)
numEdges = np.zeros(100, dtype=int)

for i in range(80):
    numNodes[i] = model.trainset[i].x.shape[0]
    numEdges[i] = model.trainset[i].y.shape[0]
    
for i in range(10):
    numNodes[i+80] = model.valset[i].x.shape[0]
    numEdges[i+80] = model.valset[i].y.shape[0]    
    
for i in range(10):
    numNodes[i+90] = model.testset[i].x.shape[0]
    numEdges[i+90] = model.testset[i].y.shape[0]

# %%
avgNodes = np.mean(numNodes)
avgEdges = np.mean(numEdges)
stdNodes = np.std(numNodes)
stdEdges = np.std(numEdges)

# %%
print("Average number of Nodes:", avgNodes)
print("Standart Deviation of Nodes:", stdNodes)
print("Average number of Edges:", avgEdges)
print("Standart Deviation of Edges:", stdEdges)
# Out:
# Average number of Nodes: 83744.49
# Standart Deviation of Nodes: 9761.448309031812
# Average number of Edges: 476507.81
# Standart Deviation of Edges: 95397.97345307656

# %%
config = yaml.load(open('gnn_train.yaml'), Loader=yaml.FullLoader)
model = InteractionGNN(config)
model.setup('fit')
sumNodes=0
sumEdges=0

numNode = np.array()

for i in range (80):
    sumNodes = sumNodes + model.trainset[i].x.shape[0]
    sumEdges = sumEdges + model.trainset[i].y.shape[0]
    #print(i)
avgNodes = sumNodes/80
avgEdges = sumEdges/80
#sample = model.trainset[0].y.shape[0]
print("Average Nodes: ", avgNodes)
print("Average Edges: ", avgEdges)
# Out:
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [particle_id] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [nhits] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [primary] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [pdgId] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [ghost] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [shared] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [module_id] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [region] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [hit_id] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/utils/loading_utils.py:65: UserWarning: OPTIONAL feature [pt] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# Defining figures of merit
# /users/PLS0150/ialadutska/data/CommonFramework/gnn4itk_cf/stages/edge_classifier/edge_classifier_stage.py:74: UserWarning: Failed to define figures of merit, due to logger unavailable
#   warnings.warn("Failed to define figures of merit, due to logger unavailable")
# Average Nodes:  84064.825
# Average Edges:  152021.1875

# %%
model.trainset[0]
# Out:
# DataBatch(hit_id=[94112], x=[94112], y=[4481808], z=[94112], r=[94112], phi=[94112], eta=[94112], region=[94112], module_index=[94112], weight=[94112], cell_count=[94112], cell_val=[94112], leta=[94112], lphi=[94112], lx=[94112], ly=[94112], lz=[94112], geta=[94112], gphi=[94112], track_edges=[2, 85285], particle_id=[85285], pt=[85285], radius=[85285], nhits=[85285], config=[2], event_id=[1], num_nodes=94112, batch=[94112], ptr=[2], edge_index=[2, 4481808], truth_map=[85285], weights=[4481808])

# %%
model = InteractionGNN(config)

# %%
model.setup('fit')
# Out:
# Defining figures of merit

# %%
sample = pd.DataFrame(model.trainset[0])

# %%
sample
# Out:
#                0                                                  1
# 0         hit_id  [tensor(1), tensor(3), tensor(4), tensor(5), t...
# 1              x  [tensor(-55.3361, dtype=torch.float64), tensor...
# 2              y  [tensor(False), tensor(False), tensor(False), ...
# 3              z  [tensor(-1.5025, dtype=torch.float64), tensor(...
# 4              r  [tensor(0.0553, dtype=torch.float64), tensor(0...
# 5            phi  [tensor(0.9969, dtype=torch.float64), tensor(-...
# 6            eta  [tensor(-3.9949, dtype=torch.float64), tensor(...
# 7         region  [tensor(1., dtype=torch.float64), tensor(1., d...
# 8   module_index  [tensor(0), tensor(0), tensor(0), tensor(0), t...
# 9         weight  [tensor(9.8641e-06, dtype=torch.float64), tens...
# 10    cell_count  [tensor(1., dtype=torch.float64), tensor(1., d...
# 11      cell_val  [tensor(0.3341, dtype=torch.float64), tensor(0...
# 12          leta  [tensor(2.0914, dtype=torch.float64), tensor(2...
# 13          lphi  [tensor(0.8442, dtype=torch.float64), tensor(0...
# 14            lx  [tensor(0.0500, dtype=torch.float64), tensor(0...
# 15            ly  [tensor(0.0563, dtype=torch.float64), tensor(0...
# 16            lz  [tensor(0.3000, dtype=torch.float64), tensor(0...
# 17          geta  [tensor(-2.0914, dtype=torch.float64), tensor(...
# 18          gphi  [tensor(-2.3364, dtype=torch.float64), tensor(...
# 19   track_edges  [[tensor(18), tensor(20), tensor(21), tensor(2...
# 20   particle_id  [tensor(4513426512543744), tensor(819655956815...
# 21            pt  [tensor(0.6210, dtype=torch.float64), tensor(0...
# 22        radius  [tensor(0.0135, dtype=torch.float64), tensor(0...
# 23         nhits  [tensor(12., dtype=torch.float64), tensor(14.,...
# 24        config  [[{'stage': 'data_reading', 'model': 'TrackMLR...
# 25      event_id                                        [000001000]
# 26     num_nodes                                      tensor(94112)
# 27         batch  [tensor(0), tensor(0), tensor(0), tensor(0), t...
# 28           ptr                         [tensor(0), tensor(94112)]
# 29    edge_index  [[tensor(8), tensor(0), tensor(0), tensor(0), ...
# 30     truth_map  [tensor(589), tensor(675), tensor(712), tensor...
# 31       weights  [tensor(1.), tensor(1.), tensor(1.), tensor(1....

# %%
graph_sizes = [sample.edge_index.shape[1] for sample in model.trainset]

# %%
sns.distplot(graph_sizes)
# Out:
# /users/PLS0150/ialadutska/.conda/envs/umap3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
graph_sizes = [sample.x.shape[0] for sample in model.trainset]

# %%
sns.distplot(graph_sizes)
# Out:
# /users/PLS0150/ialadutska/.conda/envs/umap3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Metric Debug

# %%
# %%time
with torch.no_grad():
    out = model.to("cuda")(sample.to("cuda"))
# Out:
# CPU times: user 939 ms, sys: 670 ms, total: 1.61 s
# Wall time: 7.6 s
# /users/PLS0150/ialadutska/.conda/envs/umap3/lib/python3.8/site-packages/torch/utils/checkpoint.py:31: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")

# %%
sns.distplot(torch.sigmoid(out).cpu())
# Out:
# /users/PLS0150/ialadutska/.conda/envs/umap3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sample
# Out:
# DataBatch(hit_id=[94112], x=[94112], y=[109848], z=[94112], r=[94112], phi=[94112], eta=[94112], region=[94112], module_index=[94112], weight=[94112], cell_count=[94112], cell_val=[94112], leta=[94112], lphi=[94112], lx=[94112], ly=[94112], lz=[94112], geta=[94112], gphi=[94112], track_edges=[2, 85285], particle_id=[85285], pt=[85285], radius=[85285], nhits=[85285], config=[2], event_id=[1], num_nodes=94112, batch=[94112], ptr=[2], edge_index=[2, 109848], truth_map=[85285], weights=[109848])

# %%
sample.weights.shape
# Out:
# torch.Size([109848])

# %%
(sample.weights==0).sum(), (sample.weights==1).sum(), (sample.weights==2).sum()
# Out:
# (tensor(0, device='cuda:0'),
#  tensor(109848, device='cuda:0'),
#  tensor(0, device='cuda:0'))

# %%
sample.y.sum(), (~sample.y).sum()
# Out:
# (tensor(43862, device='cuda:0'), tensor(65986, device='cuda:0'))

# %%
(sample.weights==0 & sample.y).sum()
# Out:
# tensor(0, device='cuda:0')

# %%
(sample.weights==1 & ~sample.y).sum()
# Out:
# tensor(65986, device='cuda:0')

# %%
((sample.weights==2) & sample.y).sum()
# Out:
# tensor(0, device='cuda:0')

# %%
((sample.weights==2) & ~sample.y).sum()
# Out:
# tensor(0, device='cuda:0')

# %%
model = model.to("cuda")
sample = sample.to("cuda")

# %%
with torch.no_grad():
    outputs = model.shared_evaluation(sample, 0)
# Out:
# /users/PLS0150/ialadutska/.conda/envs/umap3/lib/python3.8/site-packages/torch/utils/checkpoint.py:31: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")

# %%
outputs
# Out:
# {'loss': tensor(1.4020, device='cuda:0'),
#  'all_truth': tensor([False, False,  True,  ..., False, False, False], device='cuda:0'),
#  'target_truth': tensor([False, False,  True,  ..., False, False, False], device='cuda:0'),
#  'output': tensor([-0.6360, -0.3823, -0.6088,  ..., -0.2123, -0.0204, -0.3113],
#         device='cuda:0')}

# %%
outputs["all_truth"].sum()
# Out:
# tensor(150014, device='cuda:0')

# %%
outputs["target_truth"].sum()
# Out:
# tensor(27518, device='cuda:0')

# %%
sample.y.sum()
# Out:
# tensor(150014, device='cuda:0')

# %%
preds = torch.sigmoid(out) > 0.5

# %%
# Positives
edge_positive = preds.sum().float()

# Signal true & signal tp
sig_true = outputs["target_truth"].sum().float()
sig_true_positive = (outputs["target_truth"].bool() & preds).sum().float()
background_true_positive = (outputs["all_truth"].bool() & preds).sum().float()

# %%
sig_eff = sig_true_positive / sig_true
sig_pur = sig_true_positive / edge_positive
background_pur = background_true_positive / edge_positive

# %%
sig_eff, sig_pur, background_pur
# Out:
# (tensor(0.7390, device='cuda:0'),
#  tensor(0.0093, device='cuda:0'),
#  tensor(0.0544, device='cuda:0'))

# %% [markdown]
# ## Filter Debug

# %%
from gnn4itk_cf.stages.edge_classifier.models.filter import Filter
# Out:
# WARNING:root:FRNN is not available, install it at https://github.com/murnanedaniel/FRNN. Using PyG radius instead.

# %%
config = yaml.load(open('filter_train.yaml'), Loader=yaml.FullLoader)

# %%
model = Filter(config)
# Out:
# Defining figures of merit
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/stages/edge_classifier/models/filter.py:44: UserWarning: Failed to define figures of merit, due to logger unavailable
#   warnings.warn("Failed to define figures of merit, due to logger unavailable")

# %%
model.setup('fit')
# Out:
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [particle_id] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [nhits] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [primary] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [pdgId] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [ghost] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [shared] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [module_id] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [region] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [hit_id] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [pt] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")

# %%
sample = model.trainset[0]

# %%
sample
# Out:
# Data(track_edges=[2, 92848], particle_id=[92848], pt=[92848], radius=[92848], nhits=[92848], config=[2], event_id='000021001', num_nodes=120844, x_y=[120844], x_cell_val=[120844], x_ly=[120844], x_gphi=[120844], x_geta=[120844], x_region=[120844], x_lphi=[120844], x_x=[120844], x_lx=[120844], x_weight=[120844], x_hit_id=[120844], x_leta=[120844], x_r=[120844], x_eta=[120844], x_cell_count=[120844], x_module_index=[120844], x_phi=[120844], x_z=[120844], x_lz=[120844], edge_index=[2, 750575], y=[750575], truth_map=[92848], weights=[750575])

# %%
graph_sizes = [sample.edge_index.shape[1] for sample in model.trainset]

# %%
sns.distplot(graph_sizes)
# Out:
# /tmp/ipykernel_178689/3214984691.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(graph_sizes)
# <AxesSubplot: ylabel='Density'>

# %% [markdown]
# ### Metric Debug

# %%
# %%time
with torch.no_grad():
    out = model.to("cuda")(sample.to("cuda"))
# Out:
# CPU times: user 1.09 s, sys: 556 ms, total: 1.64 s
# Wall time: 8.48 s

# %%
sns.distplot(torch.sigmoid(out).cpu())
# Out:
# /tmp/ipykernel_63776/1067247515.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(torch.sigmoid(out).cpu())
# <AxesSubplot: ylabel='Density'>

# %%
sample
# Out:
# Data(track_edges=[2, 92848], particle_id=[92848], pt=[92848], radius=[92848], nhits=[92848], config=[2], event_id='000021001', num_nodes=120844, x_y=[120844], x_cell_val=[120844], x_ly=[120844], x_gphi=[120844], x_geta=[120844], x_region=[120844], x_lphi=[120844], x_x=[120844], x_lx=[120844], x_weight=[120844], x_hit_id=[120844], x_leta=[120844], x_r=[120844], x_eta=[120844], x_cell_count=[120844], x_module_index=[120844], x_phi=[120844], x_z=[120844], x_lz=[120844], edge_index=[2, 750575], y=[750575], truth_map=[92848], weights=[750575])

# %%
sample.weights.shape
# Out:
# torch.Size([750575])

# %%
(sample.weights==-1).sum(), (sample.weights==0).sum(), (sample.weights==1).sum(), (sample.weights==2).sum()
# Out:
# (tensor(0, device='cuda:0'),
#  tensor(54705, device='cuda:0'),
#  tensor(695870, device='cuda:0'),
#  tensor(0, device='cuda:0'))

# %%
sample.y.sum(), (~sample.y).sum()
# Out:
# (tensor(67698, device='cuda:0'), tensor(682877, device='cuda:0'))

# %%
((sample.weights==1) & sample.y).sum()
# Out:
# tensor(12993, device='cuda:0')

# %%
((sample.weights==1) & ~sample.y).sum()
# Out:
# tensor(682877, device='cuda:0')

# %%
((sample.weights==0) & sample.y).sum()
# Out:
# tensor(54705, device='cuda:0')

# %%
((sample.weights==0) & ~sample.y).sum()
# Out:
# tensor(0, device='cuda:0')

# %%
model = model.to("cuda")
sample = sample.to("cuda")

# %%
with torch.no_grad():
    outputs = model.shared_evaluation(sample, 0)

# %%
outputs
# Out:
# {'loss': tensor(1.4251, device='cuda:0'),
#  'all_truth': tensor([False, False, False,  ..., False, False, False], device='cuda:0'),
#  'target_truth': tensor([False, False, False,  ..., False, False, False], device='cuda:0'),
#  'output': tensor([-0.1153, -0.2671, -0.2979,  ...,  0.1024, -0.0105,  0.3147],
#         device='cuda:0')}

# %%
out = outputs["output"]

# %%
outputs["all_truth"].sum()
# Out:
# tensor(67698, device='cuda:0')

# %%
outputs["target_truth"].sum()
# Out:
# tensor(12993, device='cuda:0')

# %%
sample.y.sum()
# Out:
# tensor(67698, device='cuda:0')

# %%
preds = torch.sigmoid(out) > 0.4

# %%
# Positives
edge_positive = preds.sum().float()

# Signal true & signal tp
sig_true = outputs["target_truth"].sum().float()
sig_true_positive = (outputs["target_truth"].bool() & preds).sum().float()
background_true_positive = (outputs["all_truth"].bool() & preds).sum().float()

# %%
sig_eff = sig_true_positive / sig_true
sig_pur = sig_true_positive / edge_positive
background_pur = background_true_positive / edge_positive

# %%
sig_eff, sig_pur, background_pur
# Out:
# (tensor(0.8337, device='cuda:0'),
#  tensor(0.0169, device='cuda:0'),
#  tensor(0.0916, device='cuda:0'))

# %% [markdown]
# ### Normalize inputs

# %%
# Get max, mean and min of each node feature
node_features = model.hparams["node_features"]

# %%
node_features
# Out:
# ['x_r',
#  'x_phi',
#  'x_z',
#  'x_cell_count',
#  'x_cell_val',
#  'x_leta',
#  'x_lphi',
#  'x_lx',
#  'x_ly',
#  'x_lz',
#  'x_geta',
#  'x_gphi']

# %%
statistics = {}
for data in model.trainset:
    for feature in node_features:
        if feature not in statistics:
            statistics[feature] = {"max": [], "mean": [], "min": [], "std": []}
        statistics[feature]["max"].append(data[feature].max())
        statistics[feature]["mean"].append(data[feature].mean())
        statistics[feature]["min"].append(data[feature].min())
        statistics[feature]["std"].append(data[feature].std())

# Get max, mean and min of each statistic feature
for feature in statistics:
    statistics[feature]["max"] = np.max(statistics[feature]["max"])
    statistics[feature]["mean"] = np.mean(statistics[feature]["mean"])
    statistics[feature]["min"] = np.min(statistics[feature]["min"])
    statistics[feature]["std"] = np.mean(statistics[feature]["std"])

# %%
for feature in statistics:
    print(f"{feature} max: {statistics[feature]['max']:.2f}")
    print(f"{feature} mean: {statistics[feature]['mean']:.2f}")
    print(f"{feature} min: {statistics[feature]['min']:.2f}")
    print(f"{feature} std: {statistics[feature]['std']:.2f}")
    print("---")
# Out:
# x_r max: 1.03
# x_r mean: 0.32
# x_r min: 0.03
# x_r std: 0.30
# ---
# x_phi max: 1.00
# x_phi mean: -0.00
# x_phi min: -1.00
# x_phi std: 0.58
# ---
# x_z max: 2.96
# x_z mean: 0.00
# x_z min: -2.96
# x_z std: 1.06
# ---
# x_cell_count max: 345.00
# x_cell_count mean: 3.43
# x_cell_count min: 1.00
# x_cell_count std: 3.75
# ---
# x_cell_val max: 345.00
# x_cell_val mean: 1.35
# x_cell_val min: 0.00
# x_cell_val std: 1.58
# ---
# x_leta max: 2.09
# x_leta mean: 0.87
# x_leta min: 0.01
# x_leta std: 0.71
# ---
# x_lphi max: 1.57
# x_lphi mean: 1.26
# x_lphi min: 0.04
# x_lphi std: 0.28
# ---
# x_lx max: 240.00
# x_lx mean: 1.41
# x_lx min: 0.50
# x_lx std: 1.44
# ---
# x_ly max: 55.20
# x_ly mean: 2.10
# x_ly min: 0.06
# x_ly std: 3.63
# ---
# x_lz max: 7.00
# x_lz mean: 4.23
# x_lz min: 3.00
# x_lz std: 1.42
# ---
# x_geta max: 4.11
# x_geta mean: 0.88
# x_geta min: -2.09
# x_geta std: 1.44
# ---
# x_gphi max: 1.00
# x_gphi mean: -0.00
# x_gphi min: -1.00
# x_gphi std: 0.58
# ---

# %% [markdown]
# ### Inspect true edges

# %%
sample = model.trainset[0]

# %%
sample
# Out:
# DataBatch(hit_id=[94112], x=[94112], y=[4481808], z=[94112], r=[94112], phi=[94112], eta=[94112], region=[94112], module_index=[94112], weight=[94112], cell_count=[94112], cell_val=[94112], leta=[94112], lphi=[94112], lx=[94112], ly=[94112], lz=[94112], geta=[94112], gphi=[94112], track_edges=[2, 85285], particle_id=[85285], pt=[85285], radius=[85285], nhits=[85285], config=[2], event_id=[1], num_nodes=94112, batch=[94112], ptr=[2], edge_index=[2, 4481808], truth_map=[85285], weights=[4481808])

# %%
# Plot true edges in sample for one particle
unique_pids, counts_pids = sample.particle_id.unique(return_counts = True)

# %%
sample_pid = unique_pids[counts_pids >= 10][0]

# %%
sample.particle_id == sample_pid
# Out:
# tensor([False, False, False,  ..., False, False, False])

# %%
sample_true_edges = sample.track_edges[:, sample.particle_id == sample_pid]

# %%
x, y = sample.x*1000 * np.cos(sample.gphi*3.14), sample.x*1000 * np.sin(sample.gphi*3.14)
#x, y = sample.x_r*1000 * np.cos(sample.x_phi*3.14), sample.x_r*1000 * np.sin(sample.x_phi*3.14)

# %%
sample_true_edges
# Out:
# tensor([[20340, 27338, 33648, 38639, 65086, 70562, 70567, 75273, 79981, 92693],
#         [27338, 33648, 38639, 65086, 70567, 75273, 70562, 79981, 92693, 93007]])

# %%
plt.figure(figsize=(10,10))
plt.scatter(x, y, s=0.1, c="black", alpha=0.1)
plt.scatter(x[sample_true_edges[0]], y[sample_true_edges[0]], s=10, c="b")
plt.scatter(x[sample_true_edges[1]], y[sample_true_edges[1]], s=10, c="b")

# %%
plt.figure(figsize=(10,10))
plt.scatter(x, y, s=0.1, c="black", alpha=0.1)
plt.plot(x[sample_true_edges], y[sample_true_edges], c="b");

# %%
sample
# Out:
# Data(track_edges=[2, 96834], particle_id=[96834], pt=[96834], radius=[96834], nhits=[96834], config=[2], event_id='000021000', num_nodes=125576, x_phi=[125576], x_module_index=[125576], x_cell_val=[125576], x_x=[125576], x_lphi=[125576], x_lx=[125576], x_leta=[125576], x_r=[125576], x_lz=[125576], x_gphi=[125576], x_z=[125576], x_ly=[125576], x_hit_id=[125576], x_cell_count=[125576], x_eta=[125576], x_region=[125576], x_y=[125576], x_weight=[125576], x_geta=[125576], edge_index=[2, 3018436], y=[3018436], truth_map=[96834], weights=[3018436])

# %% [markdown]
# ### Debug Reversed Edges

# %%
sample
# Out:
# Data(track_edges=[2, 92848], particle_id=[92848], pt=[92848], radius=[92848], nhits=[92848], config=[2], event_id='000021001', num_nodes=120844, x_y=[120844], x_cell_val=[120844], x_ly=[120844], x_gphi=[120844], x_geta=[120844], x_region=[120844], x_lphi=[120844], x_x=[120844], x_lx=[120844], x_weight=[120844], x_hit_id=[120844], x_leta=[120844], x_r=[120844], x_eta=[120844], x_cell_count=[120844], x_module_index=[120844], x_phi=[120844], x_z=[120844], x_lz=[120844], edge_index=[2, 1501150], y=[1501150], truth_map=[92848], weights=[1501150])

# %%
# %%time
with torch.no_grad():
    out = model.to("cuda")(sample.to("cuda"))
# Out:
# CPU times: user 8.52 ms, sys: 8.05 ms, total: 16.6 ms
# Wall time: 15.9 ms

# %%
sns.distplot(torch.sigmoid(out).cpu())
# Out:
# /tmp/ipykernel_63776/1067247515.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(torch.sigmoid(out).cpu())
# <AxesSubplot: ylabel='Density'>

# %%
sample
# Out:
# Data(track_edges=[2, 92848], particle_id=[92848], pt=[92848], radius=[92848], nhits=[92848], config=[2], event_id='000021001', num_nodes=120844, x_y=[120844], x_cell_val=[120844], x_ly=[120844], x_gphi=[120844], x_geta=[120844], x_region=[120844], x_lphi=[120844], x_x=[120844], x_lx=[120844], x_weight=[120844], x_hit_id=[120844], x_leta=[120844], x_r=[120844], x_eta=[120844], x_cell_count=[120844], x_module_index=[120844], x_phi=[120844], x_z=[120844], x_lz=[120844], edge_index=[2, 1501150], y=[1501150], truth_map=[92848], weights=[1501150])

# %%
sample.weights.shape
# Out:
# torch.Size([1501150])

# %%
(sample.weights==-1).sum(), (sample.weights==0).sum(), (sample.weights==1).sum(), (sample.weights==2).sum()
# Out:
# (tensor(0, device='cuda:0'),
#  tensor(109410, device='cuda:0'),
#  tensor(1391740, device='cuda:0'),
#  tensor(0, device='cuda:0'))

# %%
sample.y.sum(), (~sample.y).sum()
# Out:
# (tensor(135396, device='cuda:0'), tensor(1365754, device='cuda:0'))

# %%
((sample.weights==1) & sample.y).sum()
# Out:
# tensor(25986, device='cuda:0')

# %%
((sample.weights==1) & ~sample.y).sum()
# Out:
# tensor(1365754, device='cuda:0')

# %%
((sample.weights==0) & sample.y).sum()
# Out:
# tensor(109410, device='cuda:0')

# %%
((sample.weights==0) & ~sample.y).sum()
# Out:
# tensor(0, device='cuda:0')

# %%
model = model.to("cuda")
sample = sample.to("cuda")

# %%
with torch.no_grad():
    outputs = model.shared_evaluation(sample, 0)

# %%
outputs
# Out:
# {'loss': tensor(1.4196, device='cuda:0'),
#  'all_truth': tensor([False, False, False,  ..., False, False, False], device='cuda:0'),
#  'target_truth': tensor([False, False, False,  ..., False, False, False], device='cuda:0'),
#  'output': tensor([0.3658, 0.3980, 0.4154,  ..., 0.9324, 0.4613, 0.9142], device='cuda:0')}

# %%
out = outputs["output"]

# %%
outputs["all_truth"].sum()
# Out:
# tensor(135396, device='cuda:0')

# %%
outputs["target_truth"].sum()
# Out:
# tensor(25986, device='cuda:0')

# %%
sample.y.sum()
# Out:
# tensor(135396, device='cuda:0')

# %%
preds = torch.sigmoid(out) > 0.2

# %%
# Positives
edge_positive = preds.sum().float()

# Signal true & signal tp
sig_true = outputs["target_truth"].sum().float()
sig_true_positive = (outputs["target_truth"].bool() & preds).sum().float()
background_true_positive = (outputs["all_truth"].bool() & preds).sum().float()

# %%
sig_eff = sig_true_positive / sig_true
sig_pur = sig_true_positive / edge_positive
background_pur = background_true_positive / edge_positive

# %%
sig_eff, sig_pur, background_pur
# Out:
# (tensor(1., device='cuda:0'),
#  tensor(0.0173, device='cuda:0'),
#  tensor(0.0902, device='cuda:0'))

# %% [markdown]
# Debug the reversing process

# %%
sample
# Out:
# Data(track_edges=[2, 92848], particle_id=[92848], pt=[92848], radius=[92848], nhits=[92848], config=[2], event_id='000021001', num_nodes=120844, x_y=[120844], x_cell_val=[120844], x_ly=[120844], x_gphi=[120844], x_geta=[120844], x_region=[120844], x_lphi=[120844], x_x=[120844], x_lx=[120844], x_weight=[120844], x_hit_id=[120844], x_leta=[120844], x_r=[120844], x_eta=[120844], x_cell_count=[120844], x_module_index=[120844], x_phi=[120844], x_z=[120844], x_lz=[120844], edge_index=[2, 750575], y=[750575], truth_map=[92848], weights=[750575])

# %%
edge_index = torch.cat([sample.edge_index, sample.edge_index.flip(0)], dim=1)
y = torch.cat([sample.y, sample.y], dim=0)
weights = torch.cat([sample.weights, sample.weights], dim=0)

# %%
edge_index
# Out:
# tensor([[     0,   1471,      0,  ..., 120840, 120840, 120843],
#         [    11,      0,   1474,  ..., 120842, 120843, 120842]])

# %%
y
# Out:
# tensor([False, False, False,  ..., False, False, False])

# %%
weights
# Out:
# tensor([1., 1., 1.,  ..., 1., 1., 1.])

# %%
# Edges and y are the same shape, I want to get unique edges and map the uniqueness to the y and weights
unique_edges, unique_edge_indices = torch.unique(edge_index, dim=1, return_inverse=True)
unique_y = torch.zeros_like(unique_edges[0], dtype=y.dtype).scatter(0, unique_edge_indices, y)
unique_weights = torch.zeros_like(unique_edges[0], dtype=weights.dtype).scatter(0, unique_edge_indices, weights)

# %%
unique_weights
# Out:
# tensor([1., 1., 1.,  ..., 1., 1., 1.])

# %%
unique_edges
# Out:
# tensor([[     0,      0,      0,  ..., 120843, 120843, 120843],
#         [    11,   1471,   1474,  ..., 120827, 120840, 120842]])

# %%
unique_y
# Out:
# tensor([False, False, False,  ..., False, False, False])

# %%
edge_index[:, y]
# Out:
# tensor([[  1482,     46,     49,  ..., 120831, 120843, 120827],
#         [     0,      2,      3,  ..., 120821, 120826, 120840]])

# %%
weights[y]
# Out:
# tensor([0., 0., 0.,  ..., 1., 0., 1.])

# %%
unique_edges[:, unique_y]
# Out:
# tensor([[     0,      2,      3,  ..., 120842, 120843, 120843],
#         [  1482,     46,     49,  ..., 120364, 120363, 120826]])

# %%
unique_weights[unique_y]
# Out:
# tensor([0., 0., 0.,  ..., 0., 0., 0.])

# %% [markdown]
# ## Test Figure of Merit Setup

# %%
import pytorch_lightning as pl
trainer = pl.Trainer(gpus=1, max_epochs=1)
# Out:
# /global/homes/d/danieltm/.conda/envs/gnn4itk/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:447: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   rank_zero_deprecation(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
# Train filter model
trainer.fit(model)
# Out:
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [particle_id] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [nhits] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [primary] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [pdgId] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [ghost] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [shared] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [module_id] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [region] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [hit_id] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# /global/u2/d/danieltm/ExaTrkX/GNN4ITkTeam/commonframework/gnn4itk_cf/utils/loading_utils.py:47: UserWarning: OPTIONAL feature [pt] not found in data
#   warnings.warn(f"OPTIONAL feature [{feature}] not found in data")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name | Type       | Params
# ------------------------------------
# 0 | net  | Sequential | 714 K
# ------------------------------------
# 714 K     Trainable params
# 0         Non-trainable params
# 714 K     Total params
# 2.859     Total estimated model params size (MB)
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# /global/homes/d/danieltm/.conda/envs/gnn4itk/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:236: PossibleUserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 128 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /global/homes/d/danieltm/.conda/envs/gnn4itk/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:1892: PossibleUserWarning: The number of training batches (20) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Epoch 0:   5%|▌         | 2/40 [00:01<00:19,  1.93it/s, loss=1.47, v_num=4644301]
# /global/homes/d/danieltm/.conda/envs/gnn4itk/lib/python3.9/site-packages/pytorch_lightning/utilities/data.py:98: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# Epoch 0: 100%|██████████| 40/40 [00:09<00:00,  4.05it/s, loss=1.31, v_num=4644301]
# `Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|██████████| 40/40 [00:10<00:00,  4.00it/s, loss=1.31, v_num=4644301]

# %%
model.logger
